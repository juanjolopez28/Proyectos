# %%
import pandas as pd
#Carga de los datos sin provincia o localidad
#Eliminación de columnas que se duplican


#Accesos a internet por cada 100 hogares por trimestre [Año,Trimestre,Accesos por cada 100 hogares,Accesos por cada 100 hab,Periodo]
df_internet_100h=pd.read_csv('Datasets/1_internet_Penetracion_100hogares_sinprovincia.csv',delimiter=',',header='infer')

#Acesos a Internet banda ancha y angos por trimestre [Banda ancha fija,Dial up,Total]
df_internet_banda_ancha_rangos=pd.read_csv('Datasets/3_internet_bandaAncha_angosta_sinprovincia.csv',delimiter=',',header='infer')
df_internet_banda_ancha_rangos.head
df_internet_banda_ancha_rangos.drop(['Año', 'Trimestre','Periodo'], axis=1, inplace=True)

#Acceso a internet por tecnología por trimestre [ADSL,Cablemodem,Fibra optica,Wireless,Otros,Total]
df_internet_tecnologia=pd.read_csv('Datasets/5_internet_accesos-por-tecnologia_sinprovincia.csv',delimiter=',',header='infer')
df_internet_tecnologia.drop(['Año', 'Trimestre','Periodo'], axis=1, inplace=True)


#Velocidad de bajada media o promedio por trimestre[Mbps (Media de bajada)]
df_internet_velocidad_media=pd.read_csv('Datasets/8_velocidad_debajada_media_internet_sinprovincia.csv',delimiter=',',header='infer')
#no tiene periodo
df_internet_velocidad_media.drop(['Año', 'Trimestre','Trimestre.1'], axis=1, inplace=True)


#Velocidad de bajada ´por rango [Entre 512 Kbps y 1 Mbps,Entre 1 Mbps y 6 Mbps , etc]
df_internet_velocidad_rango=pd.read_csv('Datasets/10_internet_accesos-por-velocidad_rango_sinprovincia.csv',delimiter=',',header='infer')
#no tiene periodo
df_internet_velocidad_rango.drop(['Año', 'Trimestre'], axis=1, inplace=True)
df_internet_velocidad_rango = df_internet_velocidad_rango.drop(df_internet_velocidad_rango.columns[-1], axis=1)


#Ingresos de internet por trimestre [Ingresos (miles de pesos)]
df_internet_ingresos=pd.read_csv('Datasets/14_internet_Ingresos.csv',delimiter=',',header='infer')
df_internet_ingresos.drop(['Año', 'Trimestre','Periodo'], axis=1, inplace=True)
df_internet_ingresos.head
# Out:
# <bound method NDFrame.head of    Ingresos (miles de pesos)
# 0                 51.432.896
# 1                 45.467.887
# 2                 42.999.944
# 3                 38.239.667
# 4                 36.676.371
# 5                 33.539.703
# 6                 31.997.445
# 7                 32.102.476
# 8                 29.946.216
# 9                 24.169.251
# 10                21.652.748
# 11                20.743.118
# 12                20.207.414
# 13                16.637.687
# 14                15.410.981
# 15                14.319.467
# 16                13.171.459
# 17                11.226.127
# 18                10.065.998
# 19                 9.678.647
# 20                 8.701.201
# 21                 7.483.980
# 22                 6.912.442
# 23                 6.534.241
# 24                 5.936.845
# 25                 5.376.899
# 26                 5.153.739
# 27                 4.701.791
# 28                 4.876.385
# 29                 3.950.441
# ...

# %%
#Cambio de tipo de datos y correción de formato
#Accesos a internet por cada 100 hogares por trimestre [Año,Trimestre,Accesos por cada 100 hogares,Accesos por cada 100 hab,Periodo]
df_internet_100h['Accesos por cada 100 hogares']=df_internet_100h['Accesos por cada 100 hogares'].str.replace(',', '.',regex=False).astype(float)

df_internet_100h['Accesos por cada 100 hab']=df_internet_100h['Accesos por cada 100 hab'].str.replace(',', '.',regex=False).astype(float)
df_internet_100h.dtypes
# Out:
# Año                               int64
# Trimestre                         int64
# Accesos por cada 100 hogares    float64
# Accesos por cada 100 hab        float64
# Periodo                          object
# dtype: object

# %%
#Acesos a Internet banda ancha y angos por trimestre [Banda ancha fija,Dial up,Total]
df_internet_banda_ancha_rangos['Banda ancha fija']=df_internet_banda_ancha_rangos['Banda ancha fija'].str.replace('.', '',regex=False).astype(int)
#en el caso de accaesos por dial up lo carga como int por eso debemos cambiar
df_internet_banda_ancha_rangos['Dial up']=df_internet_banda_ancha_rangos['Dial up'].astype(str).str.replace('.', '',regex=False).astype(int)
df_internet_banda_ancha_rangos['Total']=df_internet_banda_ancha_rangos['Total'].str.replace('.', '',regex=False).astype(int)
df_internet_banda_ancha_rangos.rename(columns={'Total': 'Total_BA'}, inplace=True)
df_internet_banda_ancha_rangos.dtypes
df_internet_banda_ancha_rangos.head
# Out:
# <bound method NDFrame.head of     Banda ancha fija  Dial up  Total_BA
# 0           10611390    12619  10624009
# 1           10476933    12861  10489794
# 2           10075184    10357  10085541
# 3            9852702    10382   9863084
# 4            9637956    10016   9647972
# 5            9561546    10016   9571562
# 6            9346183    10016   9356199
# 7            9021040    10016   9031056
# 8            8802435     9991   8812426
# 9            8783053    10128   8793181
# 10           9142891    21793   9164684
# 11           8938427    21754   8960181
# 12           8626323    21812   8648135
# 13           8451841    21814   8473655
# 14           8320223    26812   8347035
# 15           8083533    26911   8110444
# 16           8009981    27072   8037053
# 17           7842778    27444   7870222
# 18           7696594    28349   7724943
# 19           7401134     2853   7429664
# 20           7277314     2854   7305854
# 21           7223128    28545   7251673
# ...

# %%
#Acceso a internet por tecnología por trimestre [ADSL,Cablemodem,Fibra optica,Wireless,Otros,Total]
df_internet_tecnologia.dtypes
df_internet_tecnologia['ADSL']=df_internet_tecnologia['ADSL'].str.replace('.','',regex=False).astype(int)
df_internet_tecnologia['Cablemodem']=df_internet_tecnologia['Cablemodem'].str.replace('.','',regex=False).astype(int)
df_internet_tecnologia['Fibra óptica']=df_internet_tecnologia['Fibra óptica'].str.replace('.','',regex=False).astype(int)
df_internet_tecnologia['Wireless']=df_internet_tecnologia['Wireless'].astype(str).str.replace('.','',regex=False).astype(int)
df_internet_tecnologia['Otros']=df_internet_tecnologia['Otros'].astype(str).str.replace('.','',regex=False).astype(int)
df_internet_tecnologia['Total']=df_internet_tecnologia['Total'].str.replace('.','',regex=False).astype(int)
df_internet_tecnologia.rename(columns={'Otros': 'Otros_tecno'}, inplace=True)
df_internet_tecnologia.rename(columns={'Total': 'Total_tecno'}, inplace=True)
df_internet_tecnologia.dtypes
# Out:
# ADSL            int64
# Cablemodem      int64
# Fibra óptica    int64
# Wireless        int64
# Otros_tecno     int64
# Total_tecno     int64
# dtype: object

# %%
#Velocidad de bajada media o promedio por trimestre[Mbps (Media de bajada)]
df_internet_velocidad_media.dtypes
df_internet_velocidad_media['Mbps (Media de bajada)']=df_internet_velocidad_media['Mbps (Media de bajada)'].str.replace(',','.').astype(float)
df_internet_velocidad_media.dtypes
# Out:
# Mbps (Media de bajada)    float64
# dtype: object

# %%
df_internet_velocidad_rango
# Out:
#     Hasta 512 kbps  Entre 512 Kbps y 1 Mbps Entre 1 Mbps y 6 Mbps  \
# 0           34.890                  104.840             1.263.273
# 1           41.262                   28.521             1.413.208
# 2           40.174                   41.437             2.550.229
# 3           40.172                   42.024             2.531.271
# 4           39.487                   41.674             2.593.477
# 5           39.510                   42.185             2.622.638
# 6           41.038                   44.005             2.637.984
# 7           41.038                   48.690             2.651.502
# 8           42.550                   56.170             2.649.819
# 9           38.272                   28.980             2.792.684
# 10         241.713                   80.599             3.309.137
# 11         202.790                   95.980             3.444.458
# 12         166.573                  195.706             3.428.759
# ...

# %%
# Definir la función para aplicar la condición
def quitar_punto(valor):
    return valor.replace(".", "", 1) if valor.count(".") == 2 else valor


#Velocidad de bajada ´por rango [Entre 512 Kbps y 1 Mbps,Entre 1 Mbps y 6 Mbps , etc]
df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].astype(str)
df_internet_velocidad_rango.dtypes
df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].applymap(lambda x: quitar_punto(x))
df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].applymap(lambda x: (float(x)*1000) if '.' in x else float(x) )
df_internet_velocidad_rango.rename(columns={'OTROS': 'Otros_velo_rango'}, inplace=True)
df_internet_velocidad_rango.rename(columns={'Total': 'Total_velo_rango'}, inplace=True)
#verificamos que las sumas coincidan con el total

#sumas=df_internet_velocidad_rango[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS']].astype(int).sum(axis=1)
#print(sumas)

df_internet_velocidad_rango.dtypes
# Out:
# Hasta 512 kbps             float64
# Entre 512 Kbps y 1 Mbps    float64
# Entre 1 Mbps y 6 Mbps      float64
# Entre 6 Mbps y 10 Mbps     float64
# Entre 10 Mbps y 20 Mbps    float64
# Entre 20 Mbps y 30 Mbps    float64
# Más de 30 Mbps             float64
# Otros_velo_rango           float64
# Total_velo_rango           float64
# dtype: object

# %%
#Ingresos de internet por trimestre [Ingresos (miles de pesos)]
df_internet_ingresos['Ingresos (miles de pesos)']=df_internet_ingresos['Ingresos (miles de pesos)'].str.replace('.','',regex=False).astype(int)

# %%
df_tiempo=df_internet_100h[['Año','Trimestre','Periodo']]
#Guardamos en un csv los datos sin ID para el EDA
df_datos=pd.concat([df_tiempo,df_internet_100h[['Accesos por cada 100 hogares','Accesos por cada 100 hab']],df_internet_banda_ancha_rangos,df_internet_tecnologia,df_internet_velocidad_media,df_internet_velocidad_rango,df_internet_ingresos],axis=1)
df_datos.to_csv('datos_trimes_sinID.csv', index=False)

#Realizamos nuestra tablas para trabajar con la data

#1.-Tabla de tiempo tendra los siguientes atributos: ID_tiempo, Año, Trimestre, Periodo


df_tiempo.insert(0, 'ID_tiempo', range(1, len(df_internet_100h) + 1))
df_internet_100h.drop(['Año', 'Trimestre','Periodo'], axis=1, inplace=True)

# %%
#2.- Tabla para datos trimestrales
df_datos_trimestrales=pd.concat([df_tiempo['ID_tiempo'],df_internet_100h,df_internet_banda_ancha_rangos,df_internet_tecnologia,df_internet_velocidad_media,df_internet_velocidad_rango,df_internet_ingresos],axis=1)
df_datos_trimestrales.insert(0, 'ID_datos_tri', range(1, len(df_internet_100h) + 1))
df_datos_trimestrales
# Out:
#     ID_datos_tri  ID_tiempo  Accesos por cada 100 hogares  \
# 0              1          1                         73.88
# 1              2          2                         73.18
# 2              3          3                         70.58
# 3              4          4                         69.24
# 4              5          5                         67.95
# 5              6          6                         67.62
# 6              7          7                         66.31
# 7              8          8                         64.21
# 8              9          9                         62.86
# 9             10         10                         62.92
# 10            11         11                         65.79
# 11            12         12                         64.53
# 12            13         13                         62.48
# 13            14         14                         61.42
# 14            15         15                         60.69
# ...

# %%
df_datos_trimestrales.columns
# Out:
# Index(['ID_datos_tri', 'ID_tiempo', 'Accesos por cada 100 hogares',
#        'Accesos por cada 100 hab', 'Banda ancha fija', 'Dial up', 'Total_BA',
#        'ADSL', 'Cablemodem', 'Fibra óptica', 'Wireless', 'Otros_tecno',
#        'Total_tecno', 'Mbps (Media de bajada)', 'Hasta 512 kbps',
#        'Entre 512 Kbps y 1 Mbps', 'Entre 1 Mbps y 6 Mbps',
#        'Entre 6 Mbps y 10 Mbps', 'Entre 10 Mbps y 20 Mbps',
#        'Entre 20 Mbps y 30 Mbps', 'Más de 30 Mbps', 'Otros_velo_rango',
#        'Total_velo_rango', 'Ingresos (miles de pesos)'],
#       dtype='object')

# %%
#Exportamos los 2 csv
df_tiempo.to_csv('tabla_tiempo.csv', index=False)
df_datos_trimestrales.to_csv('tabla_datos_trimes.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## LIMPIEZA DATOS CON PROVINCIAS

# %%
import pandas as pd

#PROVINCIAS
#Carga de los datos sin provincia o localidad
#Eliminación de columnas que se duplican


#Accesos a internet por cada 100 hogares por trimestre [Año,Trimestre,Accesos por cada 100 hogares,Accesos por cada 100 hab,Periodo]
df_internet_100h_P=pd.read_csv('Datasets/2_internet_Penetracion_100hogares_conprovincia.csv',delimiter=',',header='infer')

#Acesos a Internet banda ancha y angos por trimestre [Banda ancha fija,Dial up,Total]
df_internet_banda_ancha_rangos_P=pd.read_csv('Datasets/4_internet_bandaAncha_angosta_conprovincia.csv',delimiter=',',header='infer')
df_internet_banda_ancha_rangos_P.head
df_internet_banda_ancha_rangos_P.drop(['Año', 'Trimestre','Provincia'], axis=1, inplace=True)

#Acceso a internet por tecnología por trimestre [ADSL,Cablemodem,Fibra optica,Wireless,Otros,Total]
df_internet_tecnologia_P=pd.read_csv('Datasets/6_internet_accesos-por-tecnologia_conprovincia.csv',delimiter=',',header='infer')
df_internet_tecnologia_P.drop(['Año', 'Trimestre','Provincia'], axis=1, inplace=True)


#Velocidad de bajada media o promedio por trimestre[Mbps (Media de bajada)]
df_internet_velocidad_media_P=pd.read_csv('Datasets/9_velocidad_debajada_media_internet_conprovincia.csv',delimiter=',',header='infer')
#no tiene periodo
df_internet_velocidad_media_P.drop(['Año', 'Trimestre','Provincia'], axis=1, inplace=True)


#Velocidad de bajada ´por rango [Entre 512 Kbps y 1 Mbps,Entre 1 Mbps y 6 Mbps , etc]
df_internet_velocidad_rango_P=pd.read_csv('Datasets/11_internet_accesos-por-velocidad_rango_conprovincia.csv',delimiter=',',header='infer')
#no tiene periodo
df_internet_velocidad_rango_P.drop(['Año', 'Trimestre','Provincia'], axis=1, inplace=True)


#Ingresos de internet por trimestre [Ingresos (miles de pesos)]
#df_internet_ingresos=pd.read_csv('Datasets/14_internet_Ingresos.csv',delimiter=',',header='infer')
#df_internet_ingresos.drop(['Año', 'Trimestre','Periodo'], axis=1, inplace=True)
#df_internet_ingresos.head

# %%
#Cambio de tipo de datos y correción de formato
#Accesos a internet por cada 100 hogares por trimestre [AÃ±o,Trimestre,Provincia,Accesos por cada 100 hogares]
df_internet_100h_P['Accesos por cada 100 hogares']=df_internet_100h_P['Accesos por cada 100 hogares'].astype(str).str.replace(',', '.',regex=False).astype(float)

df_internet_100h_P
# Out:
#       Año  Trimestre            Provincia  Accesos por cada 100 hogares
# 0    2022          1         Buenos Aires                         76.08
# 1    2022          1      Capital Federal                        111.80
# 2    2022          1            Catamarca                         58.21
# 3    2022          1                Chaco                         44.06
# 4    2022          1               Chubut                         88.05
# ..    ...        ...                  ...                           ...
# 787  2014          1           Santa Cruz                         28.94
# 788  2014          1             Santa Fe                         47.85
# 789  2014          1  Santiago Del Estero                         16.31
# 790  2014          1     Tierra Del Fuego                         63.97
# 791  2014          1              Tucumán                         33.42
#
# [792 rows x 4 columns]

# %%
df_internet_banda_ancha_rangos_P.isnull().sum()
# Out:
# Banda ancha fija    0
# Dial up             2
# Total               0
# dtype: int64

# %%
#Acesos a Internet banda ancha y angos por trimestre [Banda ancha fija,Dial up,Total]
#Convertimos los valores nulos a 0



df_internet_banda_ancha_rangos_P['Banda ancha fija'] = df_internet_banda_ancha_rangos_P['Banda ancha fija'].fillna('0')
df_internet_banda_ancha_rangos_P['Dial up'] = df_internet_banda_ancha_rangos_P['Dial up'].fillna('0')

#convertimos a in los valores quitando los puntos y los valores -0
df_internet_banda_ancha_rangos_P['Banda ancha fija']=df_internet_banda_ancha_rangos_P['Banda ancha fija'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_banda_ancha_rangos_P['Banda ancha fija']=df_internet_banda_ancha_rangos_P['Banda ancha fija'].str.replace('.', '',regex=False).astype(int)
#en el caso de accaesos por dial up lo carga como int por eso debemos cambiar
df_internet_banda_ancha_rangos_P['Dial up']=df_internet_banda_ancha_rangos_P['Dial up'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_banda_ancha_rangos_P['Dial up']=df_internet_banda_ancha_rangos_P['Dial up'].str.replace('.', '',regex=False).astype(int)
df_internet_banda_ancha_rangos_P['Total']=df_internet_banda_ancha_rangos_P['Total'].str.replace('.', '',regex=False).astype(int)
df_internet_banda_ancha_rangos_P.rename(columns={'Total': 'Total_BA_P'}, inplace=True)
df_internet_banda_ancha_rangos_P.dtypes
df_internet_banda_ancha_rangos_P.head
# Out:
# <bound method NDFrame.head of      Banda ancha fija  Dial up  Total_BA_P
# 0             4549131     6293     4555424
# 1             1415378     2163     1417541
# 2               62377        1       62378
# 3              144114        5      144119
# 4              170701      927      171628
# ..                ...      ...         ...
# 787             26304      460       26764
# 788            506000      612      506612
# 789             37124        9       37133
# 790             27272      766       28038
# 791            129944       88      130032
#
# [792 rows x 3 columns]>

# %%
df_internet_tecnologia_P.isnull().sum()
# Out:
# ADSL            1
# Cablemodem      1
# Fibra óptica    1
# Wireless        1
# Otros           1
# Total           1
# dtype: int64

# %%
# Identificar el índice del valor nulo en el dataframe
indice_valor_nulo = df_internet_tecnologia_P.isnull().any(axis=1).tolist().index(True)
print(indice_valor_nulo)
# Encontrar y mostrar la fila con valor nulo
fila_con_nulo = df_internet_tecnologia_P[df_internet_tecnologia_P.isnull().any(axis=1)]
print(fila_con_nulo)
# Out:
# 792
#     ADSL Cablemodem Fibra óptica Wireless  Otros Total
# 792  NaN        NaN          NaN      NaN    NaN   NaN

# %%
#eliminamos el valor nulo ya que es una información que no aporta
df_internet_tecnologia_P = df_internet_tecnologia_P.drop(indice_valor_nulo)

# %%
df_internet_tecnologia_P
# Out:
#         ADSL Cablemodem Fibra óptica Wireless    Otros      Total
# 0    392.045  2.728.865    1.242.121  125.521   66.872  4.555.424
# 1    102.290  1.217.225       62.308    5.784   29.934  1.417.541
# 2     14.181     15.517       29.118    1.328    2.234     62.378
# 3     32.391     64.546       36.662    8.164    2.356    144.119
# 4     44.133     66.667        9.184   30.592   21.052    171.628
# ..       ...        ...          ...      ...      ...        ...
# 787   18.927        100          381    4.092    3.264     26.764
# 788  322.662    174.296        3.059    5.951  644.000    506.612
# 789   32.567      3.598           19      915   34.000     37.133
# 790   21.618      2.837          648        1    2.934     28.038
# 791  129.717         83          121       13   98.000    130.032
#
# [792 rows x 6 columns]

# %%
#Acceso a internet por tecnología por trimestre [ADSL,Cablemodem,Fibra optica,Wireless,Otros,Total]

df_internet_tecnologia_P['ADSL']=df_internet_tecnologia_P['ADSL'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_tecnologia_P['ADSL']=df_internet_tecnologia_P['ADSL'].str.replace('.', '',regex=False).astype(int)


df_internet_tecnologia_P['Cablemodem']=df_internet_tecnologia_P['Cablemodem'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_tecnologia_P['Cablemodem']=df_internet_tecnologia_P['Cablemodem'].str.replace('.', '',regex=False).astype(int)

df_internet_tecnologia_P['Fibra óptica']=df_internet_tecnologia_P['Fibra óptica'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_tecnologia_P['Fibra óptica']=df_internet_tecnologia_P['Fibra óptica'].str.replace('.', '',regex=False).astype(int)


df_internet_tecnologia_P['Wireless']=df_internet_tecnologia_P['Wireless'].astype(str).apply( lambda x : '0' if x=='- 0'else x)
df_internet_tecnologia_P['Wireless']=df_internet_tecnologia_P['Wireless'].str.replace('.', '',regex=False).astype(int)

df_internet_tecnologia_P['Otros']=df_internet_tecnologia_P['Otros'].astype(str).str.replace('.','',regex=False).astype(int)



df_internet_tecnologia_P['Total']=df_internet_tecnologia_P['Total'].str.replace('.','',regex=False).astype(int)
df_internet_tecnologia_P.rename(columns={'Otros': 'Otros_tecno_P'}, inplace=True)
df_internet_tecnologia_P.rename(columns={'Total': 'Total_tecno_P'}, inplace=True)
df_internet_tecnologia_P.dtypes
# Out:
# ADSL             int64
# Cablemodem       int64
# Fibra óptica     int64
# Wireless         int64
# Otros_tecno_P    int64
# Total_tecno_P    int64
# dtype: object

# %%
df_internet_velocidad_media_P.dtypes
df_internet_velocidad_media_P['Mbps (Media de bajada)']=df_internet_velocidad_media_P['Mbps (Media de bajada)'].astype(str).str.replace(',','.').astype(float)
df_internet_velocidad_media_P.dtypes
# Out:
# Mbps (Media de bajada)    float64
# dtype: object

# %%
df_internet_velocidad_rango_P
# Out:
#      HASTA 512 kbps  + 512 Kbps - 1 Mbps + 1 Mbps - 6 Mbps  \
# 0            31.591               30.056           313.382
# 1           527.000                5.575            39.918
# 2            71.000              456.000             4.386
# 3           461.000                1.099            16.888
# 4           113.000                1.677            61.369
# ..              ...                  ...               ...
# 787         161.000                1.625            24.972
# 788           8.456              124.468           345.225
# 789           1.234               10.531            22.817
# 790          12.000              607.000            30.902
# 791           6.000               34.672            83.210
#
#      + 6 Mbps - 10 Mbps  + 10 Mbps - 20 Mbps  + 20 Mbps - 30 Mbps  + 30 Mbps  \
# 0               321.756              290.127              161.183  3.381.049
# 1                77.390               61.053               43.289  1.188.072
# ...

# %%
df_internet_velocidad_rango_P.columns=['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']
#['HASTA 512 kbps','+ 512 Kbps - 1 Mbps', '+ 1 Mbps - 6 Mbps','+ 6 Mbps - 10 Mbps','+ 10 Mbps - 20 Mbps'	,'+ 20 Mbps - 30 Mbps','+ 30 Mbps',	'OTROS','Total']

df_internet_velocidad_rango_P
# Out:
#      Hasta 512 kbps  Entre 512 Kbps y 1 Mbps Entre 1 Mbps y 6 Mbps  \
# 0            31.591                   30.056               313.382
# 1           527.000                    5.575                39.918
# 2            71.000                  456.000                 4.386
# 3           461.000                    1.099                16.888
# 4           113.000                    1.677                61.369
# ..              ...                      ...                   ...
# 787         161.000                    1.625                24.972
# 788           8.456                  124.468               345.225
# 789           1.234                   10.531                22.817
# 790          12.000                  607.000                30.902
# 791           6.000                   34.672                83.210
#
#      Entre 6 Mbps y 10 Mbps  Entre 10 Mbps y 20 Mbps  Entre 20 Mbps y 30 Mbps  \
# 0                   321.756                  290.127                  161.183
# ...

# %%
def quitar_punto(valor):
    return valor.replace(".", "", 1) if valor.count(".") == 2 else valor


#Velocidad de bajada ´por rango [Entre 512 Kbps y 1 Mbps,Entre 1 Mbps y 6 Mbps , etc]
df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].astype(str)
df_internet_velocidad_rango_P.dtypes
df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].applymap(lambda x: quitar_punto(x))
df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']]=df_internet_velocidad_rango_P[['Hasta 512 kbps','Entre 512 Kbps y 1 Mbps','Entre 1 Mbps y 6 Mbps','Entre 6 Mbps y 10 Mbps','Entre 10 Mbps y 20 Mbps','Entre 20 Mbps y 30 Mbps','Más de 30 Mbps','OTROS','Total']].applymap(lambda x: (float(x)*1000) if '.' in x else float(x) )
df_internet_velocidad_rango_P.rename(columns={'Total': 'Total_velo_rango_P'}, inplace=True)
df_internet_velocidad_rango_P.rename(columns={'OTROS': 'Otros_velo_rango_P'}, inplace=True)
df_internet_velocidad_rango_P
# Out:
#      Hasta 512 kbps  Entre 512 Kbps y 1 Mbps  Entre 1 Mbps y 6 Mbps  \
# 0           31591.0                  30056.0               313382.0
# 1          527000.0                   5575.0                39918.0
# 2           71000.0                 456000.0                 4386.0
# 3          461000.0                   1099.0                16888.0
# 4          113000.0                   1677.0                61369.0
# ..              ...                      ...                    ...
# 787        161000.0                   1625.0                24972.0
# 788          8456.0                 124468.0               345225.0
# 789          1234.0                  10531.0                22817.0
# 790         12000.0                 607000.0                30902.0
# 791          6000.0                  34672.0                83210.0
#
#      Entre 6 Mbps y 10 Mbps  Entre 10 Mbps y 20 Mbps  Entre 20 Mbps y 30 Mbps  \
# ...

# %%
#2.- Tabla para datos trimestrales
df_datos_trimestrales_P=pd.concat([df_internet_100h_P,df_internet_banda_ancha_rangos_P,df_internet_tecnologia_P,df_internet_velocidad_media_P,df_internet_velocidad_rango_P],axis=1)
# Guaramos en un csv para el EDA sin ID

df_datos_trimestrales_P.to_csv('datos_provincias_sinID.csv', index=False)

# %%
df_aux= df_datos_trimestrales_P[['Año','Trimestre']]

# Combinar los dataframes en función de las columnas 'Año' y 'Trimestre'
df_IDs_tiempo = pd.merge(df_tiempo, df_aux, on=['Año', 'Trimestre'], how='left')[['ID_tiempo']]

df_datos_trimestrales_P=pd.concat([df_IDs_tiempo,df_datos_trimestrales_P],axis=1)

df_datos_trimestrales_P.insert(0, 'ID_datos_Prov', range(1, len(df_internet_100h_P) + 1))


df_datos_trimestrales_P
# Out:
#      ID_datos_Prov  ID_tiempo   Año  Trimestre            Provincia  \
# 0                1          1  2022          1         Buenos Aires
# 1                2          1  2022          1      Capital Federal
# 2                3          1  2022          1            Catamarca
# 3                4          1  2022          1                Chaco
# 4                5          1  2022          1               Chubut
# ..             ...        ...   ...        ...                  ...
# 787            788         33  2014          1           Santa Cruz
# 788            789         33  2014          1             Santa Fe
# 789            790         33  2014          1  Santiago Del Estero
# 790            791         33  2014          1     Tierra Del Fuego
# 791            792         33  2014          1              Tucumán
#
#      Accesos por cada 100 hogares  Banda ancha fija  Dial up  Total_BA_P  \
# 0                           76.08           4549131     6293     4555424
# ...

# %%
df_datos_trimestrales_P.to_csv('tabla_datos_provincias.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # Limpieza datos con localidades

# %%
df_internet_localidades=pd.read_csv('Datasets/Conectividad_al_servicio_Internet.csv',delimiter=',',header='infer')
df_internet_localidades.head(3)
# Out:
#       Provincia     Partido        Localidad  Poblacion ADSL CABLEMODEM  \
# 0  BUENOS AIRES  25 de Mayo       25 de Mayo      23408   SI         SI
# 1  BUENOS AIRES  25 de Mayo  Agustín Mosconi        280   --         --
# 2  BUENOS AIRES  25 de Mayo        Del Valle        899   SI         --
#
#   DIALUP FIBRAOPTICA SATELITAL WIRELESS TELEFONIAFIJA  3G  4G       link  \
# 0     --          SI        SI       SI            SI  SI  SI  6854100.0
# 1     --          --        --       --            SI  --  --  6854010.0
# 2     --          --        SI       --            --  SI  SI  6854020.0
#
#      Latitud   Longitud
# 0 -35.433939 -60.173121
# 1 -35.739217 -60.559063
# 2 -35.897345 -60.731609

# %%
df_internet_localidades.dtypes
# Out:
# Provincia         object
# Partido           object
# Localidad         object
# Poblacion          int64
# ADSL              object
# CABLEMODEM        object
# DIALUP            object
# FIBRAOPTICA       object
# SATELITAL         object
# WIRELESS          object
# TELEFONIAFIJA     object
# 3G                object
# 4G                object
# link             float64
# Latitud          float64
# Longitud         float64
# dtype: object

# %%
df_internet_localidades.drop(['Partido', 'link'], axis=1, inplace=True)
df_internet_localidades[['ADSL','CABLEMODEM','DIALUP','FIBRAOPTICA','SATELITAL','WIRELESS','TELEFONIAFIJA','3G' ,'4G']]=df_internet_localidades[['ADSL','CABLEMODEM','DIALUP','FIBRAOPTICA','SATELITAL','WIRELESS','TELEFONIAFIJA','3G' ,'4G']].applymap(lambda x: 'NO' if x=='--' else x)

# %%
df_internet_localidades.to_csv('tabla_datos_localidades.csv', index=False)
